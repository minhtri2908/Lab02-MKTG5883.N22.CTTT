# %% [markdown]
# # Full name: Phạm Minh Trí
#
# # MSSV: 19522391
# # Lab 2

# %% [markdown]
# ## Excercise 1

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/sales.csv')

# %% [markdown]
# ## **Fixing column datatypes**

# %%
print(dataset.dtypes)
# Out:
# order_id       int64
# name          object
# ordered_at    object
# price         object
# quantity       int64
# line_total    object
# dtype: object

# %%
dataset = dataset.convert_dtypes()

# %%
dataset_1 = dataset

# %%
print(dataset_1)
# Out:
#        order_id                        name           ordered_at   price  \
# 0         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 1         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 2         10001          "SORBET" Raspberry  2018-01-01 12:14:54   $2.50
# 3         10001                        <NA>  2018-01-01 12:14:54   $1.50
# 4         10001   "CONE" Dipped Waffle Cone  2018-01-01 12:14:54   $3.50
# ...         ...                         ...                  ...     ...
# 29917     18452  "ICE CREAM" Dulce De Leche  2018-06-26 03:56:13  $-1.50
# 29918     12889  "ICE CREAM" Dark Chocolate  2018-03-03 10:06:21   $4.00
# 29919     14526    "ICE CREAM" Peanut Fudge  2018-04-05 17:33:24   $3.50
# 29920     19589   "CONE" Dipped Waffle Cone  2018-07-20 09:10:01   $3.50
# 29921     19270       "ICE CREAM" Earl Gray  2018-07-13 09:20:21   $0.50
#
#        quantity line_total
# 0             3     $10.50
# 1             1      $3.50
# ...

# %%
def drop_unit_price(data):
  data['price'] = data['price'].str.replace("$", "").str.replace("(", "").str.replace(")", "").str.replace(" ", "")
  data['line_total'] = data['line_total'].str.replace("$", "").str.replace("(", "").str.replace(")", "").str.replace(" ", "")

drop_unit_price(dataset_1)
# Out:
# <ipython-input-18-dc8131a6c359>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['price'] = data['price'].str.replace("$", "").str.replace("(", "").str.replace(")", "").str.replace(" ", "")
# <ipython-input-18-dc8131a6c359>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['line_total'] = data['line_total'].str.replace("$", "").str.replace("(", "").str.replace(")", "").str.replace(" ", "")

# %%
print(dataset_1['price'])
# Out:
# 0         3.50
# 1         3.50
# 2         2.50
# 3         1.50
# 4         3.50
#          ...
# 29917    -1.50
# 29918     4.00
# 29919     3.50
# 29920     3.50
# 29921     0.50
# Name: price, Length: 29922, dtype: string

# %%
dataset1 = dataset_1.convert_dtypes()
dataset1['line_total'] = dataset1['line_total'].astype(float)
dataset1['price'] = dataset1['price'].astype(float)

print(dataset1.dtypes)
# Out:
# order_id        Int64
# name           string
# ordered_at     string
# price         float64
# quantity        Int64
# line_total    float64
# dtype: object

# %%
dataset['price']
# Out:
# 0         3.50
# 1         3.50
# 2         2.50
# 3         1.50
# 4         3.50
#          ...
# 29917    -1.50
# 29918     4.00
# 29919     3.50
# 29920     3.50
# 29921     0.50
# Name: price, Length: 29922, dtype: string

# %% [markdown]
# ## Drop duplicate, null values

# %%
dataset_1 = dataset_1.dropna()

# %%
dataset_1 = dataset_1.drop_duplicates(subset=['order_id'])

# %% [markdown]
# ## Sanity check value ranges

# %% [markdown]
# **For price**

# %%
dataset_1['price'].describe()
# Out:
# count     9893
# unique      16
# top       2.50
# freq      2225
# Name: price, dtype: object

# %% [markdown]
# **For line total**

# %%
dataset_1['line_total'].describe()
# Out:
# count     9893
# unique      35
# top       3.00
# freq       982
# Name: line_total, dtype: object

# %% [markdown]
# ## Regular expression and lambda function to parse data.

# %%
dataset_1
# Out:
#        order_id                            name           ordered_at price  \
# 0         10000        "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  3.50
# 2         10001              "SORBET" Raspberry  2018-01-01 12:14:54  2.50
# 5         10002                 "SORBET" Lychee  2018-01-01 12:23:09  3.00
# 8         10003              "ICE CREAM" Matcha  2018-01-01 12:49:35  1.50
# 9         10004          "BEVERAGE" Iced Coffee  2018-01-01 13:22:59  2.50
# ...         ...                             ...                  ...   ...
# 29812     19995             "BEVERAGE" Espresso  2018-07-28 17:30:49  2.50
# 29814     19996          "ICE CREAM" Strawberry  2018-07-28 17:32:33  3.50
# 29816     19997  "ICE CREAM" Double Fudge Chunk  2018-07-28 17:40:40  3.50
# 29819     19998                 "SORBET" Lychee  2018-07-28 18:21:44  3.00
# 29821     19999           "SORBET" Blood Orange  2018-07-28 18:51:57  2.50
#
#        quantity line_total
# 0             3      10.50
# ...

# %%
name = dataset_1.iloc[:, 1:6].values

# %%
filtered_fruits = lambda data: str(f"{data[0]} was ordered {data[3]} quantities in {data[1]} with price {data[2]} and total is {data[4]}")

# %%
for each in name:
  print(filtered_fruits(each))
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# "ICE CREAM" Earl Gray was ordered 2 quantities in 2018-04-13 22:04:00 with price 0.50 and total is 1.00
# "ICE CREAM" Strawberry was ordered 3 quantities in 2018-04-13 22:57:17 with price 3.50 and total is 10.50
# "ICE CREAM" Dark Chocolate was ordered 1 quantities in 2018-04-13 23:37:58 with price 4.00 and total is 4.00
# "ICE CREAM" Earl Gray was ordered 1 quantities in 2018-04-14 00:06:49 with price 0.50 and total is 0.50
# "CONE" Dipped Waffle Cone was ordered 1 quantities in 2018-04-14 00:12:50 with price 3.50 and total is 3.50
# "ICE CREAM" Peanut Fudge was ordered 1 quantities in 2018-04-14 00:27:25 with price 3.50 and total is 3.50
# "CONE" Cookie Cone was ordered 2 quantities in 2018-04-14 00:55:45 with price 4.00 and total is 8.00
# "ICE CREAM" Earl Gray was ordered 2 quantities in 2018-04-14 01:17:30 with price 0.50 and total is 1.00
# ...

# %% [markdown]
# ## Exercise 2

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/job-market.csv")

# %% [markdown]
# ## Visualize top 10 first rows

# %%
data.head(10)
# Out:
#              Id                                              Title  \
# 121  37404238.0                               Fabricator/Installer
# 122  37404195.0                                        Boilermaker
# 125  37404288.0       Casual Childcare Positions  / Bondi Junction
# 126  37404267.0                                         Technician
# 127  37404230.0                                   Systems Engineer
# 129  37404237.0                 SENIOR MARKETING & PRODUCT MANAGER
# 130  37404370.0                        Operations Delivery Manager
# 131  37404228.0                                    General Manager
# 132  37404226.0                                    General Manager
# 133  37404174.0  Technical Support Executive - $70K + Super - C...
#
#                               Company                      Date   Location  \
# 121         WORKPLACE ACCESS & SAFETY  2018-10-07T00:00:00.000Z  Melbourne
# 122           RPM Contracting QLD P/l  2018-10-07T00:00:00.000Z   Brisbane
# ...

# %% [markdown]
# ## Fix column DataTypes

# %%
data = data.dropna()

# %%
data
# Out:
#                Id                                         Title  \
# 121    37404238.0                          Fabricator/Installer
# 122    37404195.0                                   Boilermaker
# 125    37404288.0  Casual Childcare Positions  | Bondi Junction
# 126    37404267.0                                    Technician
# 127    37404230.0                              Systems Engineer
# ...           ...                                           ...
# 10091  37388929.0                            Lead Kit Assembler
# 10094  37388912.0                           Executive Assistant
# 10096  37388901.0                  Receptionist / Administrator
# 10097  37388898.0     INTERNATIONAL WHOLESALE TRAVEL CONSULTANT
# 10098  37388893.0               Customer Service Representative
#
#                            Company                      Date   Location  \
# 121      WORKPLACE ACCESS & SAFETY  2018-10-07T00:00:00.000Z  Melbourne
# ...

# %%
data['Requirement'].astype("str")
# Out:
# 121      Trade qualified person with skills in welding ...
# 122      Perm rate $30. Structural steel fab & weld out...
# 125      anzuk education are searching for reliable, en...
# 126      This Australian Icon, connects the people of t...
# 127      Systems Engineer to work on BAU/Projects for a...
#                                ...
# 10091    Global leaders in medical technology | Full -T...
# 10094    The Executive Assistant will provide high leve...
# 10096    Dual position within the Engineering & Commerc...
# 10097    Travel consultants - utilise your product know...
# 10098    Liaise with internal and external stakeholders...
# Name: Requirement, Length: 5898, dtype: object

# %%
data['Id'] = data['Id'].astype(int)

# %% [markdown]
# ## Check and Clean Data

# %%
data['Date'] = data['Date'].str.split("T", 1, expand=True)[0]
# Out:
# <ipython-input-51-c92839bf9550>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data['Date'] = data['Date'].str.split("T", 1, expand=True)[0]

# %%
data['Title'] = data['Title'].str.replace("|", "/")
# Out:
# <ipython-input-56-1900351fa322>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Title'] = data['Title'].str.replace("|", "/")

# %%
data['FullDescription'] = data['FullDescription'].str.replace("<p>", "").str.replace("</p>", "").str.replace("<strong>", "").str.replace("<em>", "")

# %%
data['FullDescription'] = data['FullDescription'].str.replace("</strong>", "").str.replace("<br>", "")

# %%
data['FullDescription'].str.replace("&nbsp", "")
# Out:
# 121      ;\n        *; Secure long term role with genui...
# 122      One of Australia's best engineering workshops ...
# 125      <p style="text-align:center;">What is anzuk?  ...
# 126      This Australian Icon, connects the people of t...
# 127      The Company  This organisation is well-establi...
#                                ...
# 10091    A new and exciting opportunity for driven indi...
# 10094    V/Line, Victoria's largest regional passenger ...
# 10096    Randstad are currently recruiting for a versat...
# 10097    Travel consultants - utilise your product know...
# 10098    The CompanyOur client are a global market lead...
# Name: FullDescription, Length: 5898, dtype: object

# %%
data['FullDescription']
# Out:
# 121      &nbsp;\n        *&nbsp; Secure long term role ...
# 122      One of Australia's best engineering workshops ...
# 125      <p style="text-align:center;">What is anzuk?  ...
# 126      This Australian Icon, connects the people of t...
# 127      The Company  This organisation is well-establi...
#                                ...
# 10091    A new and exciting opportunity for driven indi...
# 10094    V/Line, Victoria's largest regional passenger ...
# 10096    Randstad are currently recruiting for a versat...
# 10097    Travel consultants - utilise your product know...
# 10098    The CompanyOur client are a global market lead...
# Name: FullDescription, Length: 5898, dtype: object
